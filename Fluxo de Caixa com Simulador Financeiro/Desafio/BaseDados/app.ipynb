# %% [markdown]
# #### INSTALAÇÃO DAS BIBILIOTECAS

# %%
# py -m pip install pandas openpyxl

# %% [markdown]
# #### UTILIZAÇÃO DE BIBLIOTECAS

# %%
import pandas as pd

# %%
# LER O ARQUIVO EXCEL
df = pd.read_excel('Receitas.xlsx')

# EXIBIR O CONTEÚDO DO ARQUIVO
print(df.head())
# Out:
#   DataEmissao DataVencimento      NFe  cdProduto  cdVendedor        Vendedor  \
# 0  2019-01-01     2019-01-28  1748677       1019         215  Carla Ferreira
# 1  2019-01-01     2019-01-12  1797750       1048         125   Gustavo Gomes
# 2  2019-01-01     2019-01-14  1807663       1048         183  Isabella Sousa
# 3  2019-01-01     2019-01-17  1816377       1048         215  Carla Ferreira
# 4  2019-01-01     2019-01-18  1834054       1048         125   Gustavo Gomes
#
#        Supervisor   Equipe Vendas  QtdItens  PrecoUnitario  ValorBruto
# 0    Diego Araujo          Varejo         2           9.86       19.72
# 1  Diogo Carvalho  Distribuidoras        27           1.64       44.28
# 2     Emily Rocha          Varejo         9           1.68       15.12
# 3    Diego Araujo          Varejo         9           1.69       15.21
# 4  Diogo Carvalho  Distribuidoras        18           1.59       28.62

# %% [markdown]
# ### 🧹 3. Tratamento de dados (ETL básico)
#
# #### Aqui você começa a agir como analista de dados de verdade:

# %%
# Remover Linhas vazias
df = df.dropna()
# Exibir o conteúdo do arquivo
print(df.head())
# Out:
#   DataEmissao DataVencimento      NFe  cdProduto  cdVendedor        Vendedor  \
# 0  2019-01-01     2019-01-28  1748677       1019         215  Carla Ferreira
# 1  2019-01-01     2019-01-12  1797750       1048         125   Gustavo Gomes
# 2  2019-01-01     2019-01-14  1807663       1048         183  Isabella Sousa
# 3  2019-01-01     2019-01-17  1816377       1048         215  Carla Ferreira
# 4  2019-01-01     2019-01-18  1834054       1048         125   Gustavo Gomes
#
#        Supervisor   Equipe Vendas  QtdItens  PrecoUnitario  ValorBruto
# 0    Diego Araujo          Varejo         2           9.86       19.72
# 1  Diogo Carvalho  Distribuidoras        27           1.64       44.28
# 2     Emily Rocha          Varejo         9           1.68       15.12
# 3    Diego Araujo          Varejo         9           1.69       15.21
# 4  Diogo Carvalho  Distribuidoras        18           1.59       28.62

# %%
# Converter Tipos
df['DataEmissao'] = pd.to_datetime(df['DataEmissao'])
print(df['DataEmissao'].dtype)
# Exibir tipos de dados
print(df.dtypes)
# Out:
# datetime64[us]
# DataEmissao       datetime64[us]
# DataVencimento    datetime64[us]
# NFe                        int64
# cdProduto                  int64
# cdVendedor                 int64
# Vendedor                     str
# Supervisor                   str
# Equipe Vendas                str
# QtdItens                   int64
# PrecoUnitario            float64
# ValorBruto               float64
# dtype: object

# %%
print(df.head(3))
# Out:
#   DataEmissao DataVencimento      NFe  cdProduto  cdVendedor        Vendedor  \
# 0  2019-01-01     2019-01-28  1748677       1019         215  Carla Ferreira
# 1  2019-01-01     2019-01-12  1797750       1048         125   Gustavo Gomes
# 2  2019-01-01     2019-01-14  1807663       1048         183  Isabella Sousa
#
#        Supervisor   Equipe Vendas  QtdItens  PrecoUnitario  ValorBruto
# 0    Diego Araujo          Varejo         2           9.86       19.72
# 1  Diogo Carvalho  Distribuidoras        27           1.64       44.28
# 2     Emily Rocha          Varejo         9           1.68       15.12
