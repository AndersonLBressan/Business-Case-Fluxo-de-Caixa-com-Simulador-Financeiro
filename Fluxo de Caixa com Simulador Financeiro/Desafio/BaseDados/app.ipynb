# %% [markdown]
# #### INSTALAÇÃO DAS BIBILIOTECAS

# %%
# py -m pip install pandas openpyxl

# %% [markdown]
# #### UTILIZAÇÃO DE BIBLIOTECAS

# %%
import pandas as pd

# %%
# Criar a função para importar osa valores em xlsx

def importar_xlsx(caminho_arquivo, nome_aba=None):
    df = pd.read_excel(caminho_arquivo, sheet_name=nome_aba)
    return df

# df = importar_xlsx('Receitas.xlsx',nome_aba=0)
# print(df.head(4))

df = pd.read_excel('Despesas.xlsx', usecols=['DataEmissao'])
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\Power_BI_And_Python\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\parsers\python_parser.py:792, in PythonParser._handle_usecols(self, columns, usecols_key, num_original_columns)
#     791 try:
# --> 792     col_indices.append(usecols_key.index(col))
#     793 except ValueError:
#
# ValueError: list.index(x): x not in list
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 10
#       6
#       7 # df = importar_xlsx('Receitas.xlsx',nome_aba=0)
#       8 # print(df.head(4))
#       9
# ---> 10 df = pd.read_excel('Despesas.xlsx', usecols=['DataEmissao'])
#      11 print(df.head())
#
# ...
